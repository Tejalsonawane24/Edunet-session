# %% [markdown]
# # Implementation of Neural Network Concepts

# %% [markdown]
# ### Objective
# - Build and train a Feedforward Neural Network (FNN) using TensorFlow/Keras for predicting crop yield.
# - Train the neural network on the dataset to learn patterns and relationships between environmental factors and crop yield.

# %% [markdown]
# ### Problem
# The objective of this project is to develop an Artificial Neural Network (ANN) model to predict crop yield based on various environmental and agricultural factors. These factors include temperature, humidity, rainfall, soil quality, and fertilizer used. This model can assist in agricultural decision-making, helping farmers to forecast crop yields more accurately, optimize farming practices, and plan better for future harvests.

# %% [markdown]
# ### Solution
# We'll go through the following steps:
# 1.	Install Required Libraries
# 2.	Feature Selection
# 3.	Normalize the data
# 4.	Split the data into training and testing sets
# 5.	Build the ANN model
# 6.	Compile the model
# 7.	Train the model
# 8.	Evaluate the model

# %% [markdown]
# ### Procedures
# 1. Install Required Libraries

# %%
#pip list --outdated
# Out:
# Package                           Version            Latest               Type
# --------------------------------- ------------------ -------------------- -----
# absl-py                           2.1.0              2.3.1                wheel
# aiobotocore                       2.12.3             2.25.1               wheel
# aiohttp                           3.9.5              3.13.2               wheel
# aioitertools                      0.7.1              0.13.0               wheel
# aiosignal                         1.2.0              1.4.0                wheel
# alabaster                         0.7.16             1.0.0                wheel
# alembic                           1.14.1             1.17.1               wheel
# altair                            5.0.1              5.5.0                wheel
# anaconda-client                   1.12.3             1.13.0               wheel
# anaconda-cloud-auth               0.5.1              0.7.2                wheel
# annotated-types                   0.6.0              0.7.0                wheel
# anyio                             4.2.0              4.11.0               wheel
# archspec                          0.2.3              0.2.5                wheel
# argon2-cffi                       21.3.0             25.1.0               wheel
# argon2-cffi-bindings              21.2.0             25.1.0               wheel
# arrow                             1.2.3              1.4.0                wheel
# astroid                           2.14.2             4.0.2                wheel
# astropy                           6.1.0              7.1.1                wheel
# astropy-iers-data                 0.2024.6.3.0.31.14 0.2025.11.10.0.38.31 wheel
# asttokens                         2.0.5              3.0.0                wheel
# async-lru                         2.0.4              2.0.5                wheel
# async-timeout                     4.0.3              5.0.1                wheel
# atomicwrites                      1.4.0              1.4.1                sdist
# attrs                             23.1.0             25.4.0               wheel
# Automat                           20.2.0             25.4.16              wheel
# autopep8                          2.0.4              2.3.2                wheel
# Babel                             2.11.0             2.17.0               wheel
# bcrypt                            3.2.0              5.0.0                wheel
# beautifulsoup4                    4.12.3             4.14.2               wheel
# black                             24.4.2             25.11.0              wheel
# bleach                            4.1.0              6.3.0                wheel
# blinker                           1.6.2              1.9.0                wheel
# bokeh                             3.4.1              3.8.1                wheel
# boltons                           23.0.0             25.0.0               wheel
# botocore                          1.34.69            1.40.70              wheel
# Bottleneck                        1.3.7              1.6.0                wheel
# branca                            0.8.1              0.8.2                wheel
# Brotli                            1.0.9              1.2.0                wheel
# cachetools                        5.3.3              6.2.1                wheel
# catboost                          1.2.7              1.2.8                wheel
# cffi                              1.16.0             2.0.0                wheel
# chardet                           4.0.0              5.2.0                wheel
# charset-normalizer                2.0.4              3.4.4                wheel
# choreographer                     1.2.0              1.2.1                wheel
# click                             8.1.7              8.3.0                wheel
# cloudpickle                       2.2.1              3.1.2                wheel
# comm                              0.2.1              0.2.3                wheel
# comtypes                          1.4.7              1.4.13               wheel
# conda_index                       0.5.0              0.7.0                wheel
# conda-pack                        0.7.1              0.8.1                wheel
# conda-package-handling            2.3.0              2.4.0                wheel
# conda_package_streaming           0.10.0             0.12.0               wheel
# contourpy                         1.2.0              1.3.3                wheel
# cryptography                      42.0.5             46.0.3               wheel
# cssselect                         1.2.0              1.3.0                wheel
# cycler                            0.11.0             0.12.1               wheel
# Cython                            3.1.6              3.2.0                wheel
# cytoolz                           0.12.2             1.1.0                wheel
# dask                              2024.5.0           2025.11.0            wheel
# dask-expr                         1.1.0              2.0.0                wheel
# databricks-sdk                    0.71.0             0.73.0               wheel
# datasets                          4.3.0              4.4.1                wheel
# datashader                        0.16.2             0.18.2               wheel
# debugpy                           1.6.7              1.8.17               wheel
# decorator                         5.1.1              5.2.1                wheel
# diff-match-patch                  20200713           20241021             wheel
# dill                              0.3.8              0.4.0                wheel
# distributed                       2024.5.0           2025.11.0            wheel
# dlib                              19.24.6            20.0.0               sdist
# dnspython                         2.6.1              2.8.0                wheel
# docstring-to-markdown             0.11               0.17                 wheel
# docutils                          0.18.1             0.22.3               wheel
# et-xmlfile                        1.1.0              2.0.0                wheel
# executing                         0.8.3              2.2.1                wheel
# fastapi                           0.115.7            0.121.1              wheel
# fastapi-cli                       0.0.5              0.0.16               wheel
# fastjsonschema                    2.16.2             2.21.2               wheel
# filelock                          3.13.1             3.20.0               wheel
# flake8                            7.0.0              7.3.0                wheel
# Flask                             3.0.3              3.1.2                wheel
# flatbuffers                       24.3.25            25.9.23              wheel
# folium                            0.19.2             0.20.0               wheel
# fonttools                         4.51.0             4.60.1               wheel
# frozendict                        2.4.2              2.4.6                wheel
# frozenlist                        1.4.0              1.8.0                wheel
# fsspec                            2024.3.1           2025.10.0            wheel
# fst-pso                           1.8.1              1.9.0                wheel
# FuzzyTM                           2.0.5              2.0.9                wheel
# gensim                            4.3.2              4.4.0                wheel
# gitdb                             4.0.7              4.0.12               wheel
# GitPython                         3.1.37             3.1.45               wheel
# google-ai-generativelanguage      0.6.10             0.9.0                wheel
# google-api-core                   2.24.0             2.28.1               wheel
# google-api-python-client          2.156.0            2.187.0              wheel
# google-auth                       2.37.0             2.43.0               wheel
# google-auth-httplib2              0.2.0              0.2.1                wheel
# google-generativeai               0.8.3              0.8.5                wheel
# googleapis-common-protos          1.66.0             1.72.0               wheel
# graphviz                          0.20.3             0.21                 wheel
# greenlet                          3.0.1              3.2.4                wheel
# grpcio                            1.68.1             1.76.0               wheel
# grpcio-status                     1.68.1             1.76.0               wheel
# h11                               0.14.0             0.16.0               wheel
# h5py                              3.11.0             3.15.1               wheel
# holoviews                         1.19.0             1.22.0               wheel
# httpcore                          1.0.2              1.0.9                wheel
# httplib2                          0.22.0             0.31.0               wheel
# httpx                             0.27.0             0.28.1               wheel
# httpx-sse                         0.4.0              0.4.3                wheel
# huggingface-hub                   0.25.1             1.1.2                wheel
# hvplot                            0.10.0             0.12.1               wheel
# idna                              3.7                3.11                 wheel
# imagecodecs                       2024.6.1           2025.11.11           wheel
# imageio                           2.33.1             2.37.2               wheel
# imbalanced-learn                  0.12.3             0.14.0               wheel
# importlib-metadata                7.0.1              8.7.0                wheel
# importlib_resources               6.4.5              6.5.2                wheel
# incremental                       22.10.0            24.7.2               wheel
# iniconfig                         1.1.1              2.3.0                wheel
# intake                            0.7.0              2.0.8                wheel
# ipykernel                         6.28.0             7.1.0                wheel
# ipython                           8.25.0             9.7.0                wheel
# ipywidgets                        7.8.1              8.1.8                wheel
# isort                             5.13.2             7.0.0                wheel
# itemadapter                       0.3.0              0.12.2               wheel
# itemloaders                       1.1.0              1.3.2                wheel
# jaraco.classes                    3.2.1              3.4.0                wheel
# jax                               0.4.33             0.8.0                wheel
# jaxlib                            0.4.33             0.8.0                wheel
# jedi                              0.18.1             0.19.2               wheel
# jellyfish                         1.0.1              1.2.1                wheel
# Jinja2                            3.1.4              3.1.6                wheel
# jiter                             0.8.2              0.12.0               wheel
# joblib                            1.3.2              1.5.2                wheel
# json5                             0.9.6              0.12.1               wheel
# jsonpointer                       2.1                3.0.0                wheel
# jsonschema                        4.23.0             4.25.1               wheel
# jsonschema-specifications         2023.7.1           2025.9.1             wheel
# jupyter                           1.0.0              1.1.1                wheel
# jupyter_client                    8.6.0              8.6.3                wheel
# jupyter_core                      5.7.2              5.9.1                wheel
# jupyter-events                    0.10.0             0.12.0               wheel
# jupyter-lsp                       2.2.0              2.3.0                wheel
# jupyter_server                    2.14.1             2.17.0               wheel
# jupyter_server_terminals          0.4.4              0.5.3                wheel
# jupyterlab                        4.0.11             4.4.10               wheel
# jupyterlab-pygments               0.1.2              0.3.0                wheel
# jupyterlab_server                 2.25.1             2.28.0               wheel
# jupyterlab-widgets                1.0.0              3.0.16               wheel
# kaggle                            1.6.17             1.7.4.5              wheel
# keyring                           24.3.1             25.6.0               wheel
# kiwisolver                        1.4.4              1.4.9                wheel
# langchain                         0.3.13             1.0.5                wheel
# langchain-community               0.3.13             0.4.1                wheel
# langchain-core                    0.3.28             1.0.4                wheel
# langchain-experimental            0.3.4              0.4.0                wheel
# langchain-google-genai            2.0.7              3.0.2                wheel
# langchain-text-splitters          0.3.4              1.0.0                wheel
# langcodes                         3.4.1              3.5.0                wheel
# langsmith                         0.1.147            0.4.42               wheel
# lazy-object-proxy                 1.10.0             1.12.0               wheel
# lckr_jupyterlab_variableinspector 3.1.0              3.2.4                wheel
# libarchive-c                      2.9                5.3                  wheel
# lightgbm                          4.4.0              4.6.0                wheel
# linkify-it-py                     2.0.0              2.0.3                wheel
# lmdb                              1.4.1              1.7.5                wheel
# lxml                              5.2.1              6.0.2                wheel
# lz4                               4.3.2              4.4.5                wheel
# marisa-trie                       1.2.1              1.3.1                wheel
# Markdown                          3.4.1              3.10                 wheel
# markdown-it-py                    2.2.0              4.0.0                wheel
# MarkupSafe                        2.1.3              3.0.3                wheel
# marshmallow                       3.23.2             4.1.0                wheel
# matplotlib-inline                 0.1.6              0.2.1                wheel
# mdit-py-plugins                   0.3.0              0.5.0                wheel
# mdurl                             0.1.0              0.1.2                wheel
# mediapipe                         0.10.14            0.10.21              wheel
# mistune                           2.0.4              3.1.4                wheel
# mkl-service                       2.5.2              2.6.0                wheel
# ml-dtypes                         0.4.1              0.5.3                wheel
# mlflow                            3.2.0              3.6.0                wheel
# mlflow-skinny                     3.2.0              3.6.0                wheel
# more-itertools                    10.1.0             10.8.0               wheel
# msgpack                           1.0.3              1.1.2                wheel
# multidict                         6.0.4              6.7.0                wheel
# multimethod                       1.4                2.0.1                wheel
# multipledispatch                  0.6.0              1.0.0                wheel
# multiprocess                      0.70.16            0.70.18              wheel
# mypy                              1.10.0             1.18.2               wheel
# mypy-extensions                   1.0.0              1.1.0                wheel
# namex                             0.0.8              0.1.0                wheel
# nbclient                          0.8.0              0.10.2               wheel
# nbconvert                         7.10.0             7.16.6               wheel
# nbformat                          5.9.2              5.10.4               wheel
# networkx                          3.2.1              3.5                  wheel
# nltk                              3.8.1              3.9.2                wheel
# notebook                          7.0.8              7.4.7                wheel
# notebook_shim                     0.2.3              0.2.4                wheel
# numexpr                           2.11.0             2.14.1               wheel
# numpy                             1.26.4             2.3.4                wheel
# numpydoc                          1.7.0              1.9.0                wheel
# openai                            1.58.1             2.7.2                wheel
# opencv-contrib-python             4.10.0.84          4.12.0.88            wheel
# opencv-python                     4.10.0.84          4.12.0.88            wheel
# openpyxl                          3.1.2              3.1.5                wheel
# optree                            0.12.1             0.17.0               wheel
# optuna                            4.5.0              4.6.0                wheel
# overrides                         7.4.0              7.7.0                wheel
# packaging                         23.2               25.0                 wheel
# pandas                            2.1.4              2.3.3                wheel
# pandas-profiling                  3.0.0              3.2.0                wheel
# pandocfilters                     1.5.0              1.5.1                wheel
# panel                             1.4.4              1.8.3                wheel
# param                             2.1.0              2.2.1                wheel
# paramiko                          2.8.1              4.0.0                wheel
# parsel                            1.8.1              1.10.0               wheel
# parso                             0.8.3              0.8.5                wheel
# partd                             1.4.1              1.4.2                wheel
# pathspec                          0.10.3             0.12.1               wheel
# patsy                             0.5.6              1.0.2                wheel
# pexpect                           4.8.0              4.9.0                wheel
# pillow                            10.3.0             12.0.0               wheel
# pkginfo                           1.10.0             1.12.1.2             wheel
# platformdirs                      3.10.0             4.5.0                wheel
# plotly                            5.22.0             6.4.0                wheel
# pluggy                            1.0.0              1.6.0                wheel
# prometheus-client                 0.14.1             0.23.1               wheel
# prompt-toolkit                    3.0.43             3.0.52               wheel
# Protego                           0.1.16             0.5.0                wheel
# proto-plus                        1.25.0             1.26.1               wheel
# protobuf                          4.25.8             6.33.0               wheel
# psutil                            5.9.0              7.1.3                wheel
# pure-eval                         0.2.2              0.2.3                wheel
# pyasn1                            0.4.8              0.6.1                wheel
# pyasn1-modules                    0.2.8              0.4.2                wheel
# pycodestyle                       2.11.1             2.14.0               wheel
# pycparser                         2.21               2.23                 wheel
# pyct                              0.5.0              0.6.0                wheel
# pycurl                            7.45.2             7.45.7               wheel
# pydantic                          2.10.4             2.12.4               wheel
# pydantic_core                     2.27.2             2.41.5               wheel
# pydantic-settings                 2.7.0              2.12.0               wheel
# pydeck                            0.8.0              0.9.1                wheel
# PyDispatcher                      2.0.5              2.0.7                wheel
# pydot                             3.0.4              4.0.1                wheel
# pyerfa                            2.0.1.4            2.0.1.5              wheel
# pyflakes                          3.2.0              3.4.0                wheel
# pyFUME                            0.2.25             0.3.4                wheel
# Pygments                          2.15.1             2.19.2               wheel
# PyJWT                             2.8.0              2.10.1               wheel
# pylint                            2.16.2             4.0.2                wheel
# pylint-venv                       3.0.3              3.0.4                wheel
# PyNaCl                            1.5.0              1.6.1                wheel
# pyodbc                            5.0.1              5.3.0                wheel
# pyOpenSSL                         24.0.0             25.3.0               wheel
# pyparsing                         3.0.9              3.2.5                wheel
# PyQt5                             5.15.10            5.15.11              wheel
# PyQt5-sip                         12.13.0            12.17.1              wheel
# PyQtWebEngine                     5.15.6             5.15.7               wheel
# pytest                            7.4.4              9.0.0                wheel
# python-dotenv                     0.21.0             1.2.1                wheel
# python-json-logger                2.0.7              4.0.0                wheel
# python-lsp-server                 1.10.0             1.13.1               wheel
# python-slugify                    5.0.2              8.0.4                wheel
# python-snappy                     0.6.1              0.7.3                wheel
# pytoolconfig                      1.2.6              1.3.1                wheel
# pyttsx3                           2.98               2.99                 wheel
# pytz                              2024.1             2025.2               wheel
# pyviz_comms                       3.0.2              3.0.6                wheel
# pywavelets                        1.5.0              1.9.0                wheel
# pywin32                           305.1              311                  wheel
# pywin32-ctypes                    0.2.2              0.2.3                wheel
# pywinpty                          2.0.10             3.0.2                wheel
# PyYAML                            6.0.1              6.0.3                wheel
# pyzmq                             25.1.2             27.1.0               wheel
# qstylizer                         0.2.2              0.2.4                wheel
# QtAwesome                         1.2.2              1.4.0                wheel
# qtconsole                         5.5.1              5.7.0                wheel
# QtPy                              2.4.1              2.4.3                wheel
# queuelib                          1.6.2              1.8.0                wheel
# referencing                       0.30.2             0.37.0               wheel
# regex                             2023.10.3          2025.11.3            wheel
# requests                          2.32.2             2.32.5               wheel
# requests-file                     1.5.1              3.0.1                wheel
# rich                              13.3.5             14.2.0               wheel
# rope                              1.12.0             1.14.0               wheel
# rpds-py                           0.10.6             0.28.0               wheel
# Rtree                             1.0.1              1.4.1                wheel
# ruamel.yaml                       0.17.21            0.18.16              wheel
# s3fs                              2024.3.1           2025.10.0            wheel
# safetensors                       0.4.5              0.6.2                wheel
# schemdraw                         0.15               0.21                 wheel
# scikit-base                       0.7.8              0.13.0               wheel
# scikit-image                      0.23.2             0.25.2               wheel
# scipy                             1.11.4             1.16.3               wheel
# Scrapy                            2.11.1             2.13.3               wheel
# screen_brightness_control         0.23.0             0.24.3               wheel
# semver                            3.0.2              3.0.4                wheel
# Send2Trash                        1.8.2              1.8.3                wheel
# service-identity                  18.1.0             24.2.0               wheel
# setuptools                        75.1.0             80.9.0               wheel
# sip                               6.7.12             6.14.0               wheel
# six                               1.16.0             1.17.0               wheel
# smart-open                        5.2.1              7.5.0                wheel
# smmap                             4.0.0              5.0.2                wheel
# sniffio                           1.3.0              1.3.1                wheel
# snowballstemmer                   2.2.0              3.0.1                wheel
# sounddevice                       0.5.0              0.5.3                wheel
# soupsieve                         2.5                2.8                  wheel
# spacy                             3.8.7              3.8.8                wheel
# Sphinx                            7.3.7              8.2.3                wheel
# sphinxcontrib-applehelp           1.0.2              2.0.0                wheel
# sphinxcontrib-devhelp             1.0.2              2.0.0                wheel
# sphinxcontrib-htmlhelp            2.0.0              2.1.0                wheel
# sphinxcontrib-qthelp              1.0.3              2.0.0                wheel
# sphinxcontrib-serializinghtml     1.1.10             2.0.0                wheel
# spyder                            5.5.1              6.1.0                wheel
# spyder-kernels                    2.5.0              3.1.1                wheel
# SQLAlchemy                        2.0.30             2.0.44               wheel
# stack-data                        0.2.0              0.6.3                wheel
# starlette                         0.45.3             0.50.0               wheel
# statsmodels                       0.14.2             0.14.5               wheel
# streamlit                         1.40.2             1.51.0               wheel
# sympy                             1.12               1.14.0               wheel
# tables                            3.9.2              3.10.2               wheel
# tblib                             1.7.0              3.2.1                wheel
# tenacity                          8.2.2              9.1.2                wheel
# tensorboard                       2.17.1             2.20.0               wheel
# tensorflow                        2.17.0             2.20.0               wheel
# tensorflow-intel                  2.17.0             2.18.0               wheel
# termcolor                         2.4.0              3.2.0                wheel
# terminado                         0.17.1             0.18.1               wheel
# textblob                          0.15.3             0.19.0               wheel
# textdistance                      4.2.1              4.6.3                wheel
# thinc                             8.3.6              9.1.1                wheel
# tifffile                          2023.4.12          2025.10.16           wheel
# tinycss2                          1.2.1              1.4.0                wheel
# tldextract                        3.2.0              5.3.0                wheel
# tokenizers                        0.20.0             0.22.1               wheel
# tomli                             2.0.1              2.3.0                wheel
# tomlkit                           0.11.1             0.13.3               wheel
# toolz                             0.12.0             1.1.0                wheel
# torch                             2.4.1              2.9.0                wheel
# tornado                           6.4.1              6.5.2                wheel
# tqdm                              4.66.4             4.67.1               wheel
# transformers                      4.45.0             4.57.1               wheel
# truststore                        0.8.0              0.10.4               wheel
# Twisted                           23.10.0            25.5.0               wheel
# twisted-iocpsupport               1.0.2              25.10.1              wheel
# typing_extensions                 4.12.2             4.15.0               wheel
# tzdata                            2023.3             2025.2               wheel
# uc-micro-py                       1.0.1              1.0.3                wheel
# ujson                             5.10.0             5.11.0               wheel
# unicodedata2                      15.1.0             17.0.0               wheel
# Unidecode                         1.2.0              1.4.0                wheel
# uritemplate                       4.1.1              4.2.0                wheel
# urllib3                           2.2.2              2.5.0                wheel
# visions                           0.7.1              0.8.1                wheel
# w3lib                             2.1.2              2.3.1                wheel
# watchdog                          4.0.1              6.0.0                wheel
# wcwidth                           0.2.5              0.2.14               wheel
# weasel                            0.4.1              0.4.2                wheel
# websocket-client                  1.8.0              1.9.0                wheel
# Werkzeug                          3.0.3              3.1.3                wheel
# whatthepatch                      1.0.2              1.0.7                wheel
# wheel                             0.44.0             0.45.1               wheel
# widgetsnbextension                3.6.6              4.0.15               wheel
# wrapt                             1.14.1             2.0.1                wheel
# xarray                            2023.6.0           2025.10.1            wheel
# xgboost                           2.1.3              3.1.1                wheel
# xlwings                           0.31.4             0.33.16              wheel
# xyzservices                       2022.9.0           2025.10.0            wheel
# yapf                              0.40.2             0.43.0               wheel
# yarl                              1.9.3              1.22.0               wheel
# zipp                              3.17.0             3.23.0               wheel
# zope.interface                    5.4.0              8.1                  wheel
# zstandard                         0.23.0             0.25.0               wheel
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (D:\edunet_foundation\anaconda3\Lib\site-packages)

# %%
#pip install --upgrade tensorflow
# Out:
# Requirement already satisfied: tensorflow in d:\edunet_foundation\anaconda3\lib\site-packages (2.17.0)Note: you may need to restart the kernel to use updated packages.
#
# Collecting tensorflow
#   Using cached tensorflow-2.20.0-cp312-cp312-win_amd64.whl.metadata (4.6 kB)
# Requirement already satisfied: absl-py>=1.0.0 in d:\edunet_foundation\anaconda3\lib\site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\edunet_foundation\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in d:\edunet_foundation\anaconda3\lib\site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\edunet_foundation\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in d:\edunet_foundation\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\edunet_foundation\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in d:\edunet_foundation\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in d:\edunet_foundation\anaconda3\lib\site-packages (from tensorflow) (23.2)
# Collecting protobuf>=5.28.0 (from tensorflow)
#   Using cached protobuf-6.33.0-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\edunet_foundation\anaconda3\lib\site-packages (from tensorflow) (2.32.2)
# Requirement already satisfied: setuptools in d:\edunet_foundation\anaconda3\lib\site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in d:\edunet_foundation\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\edunet_foundation\anaconda3\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in d:\edunet_foundation\anaconda3\lib\site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in d:\edunet_foundation\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\edunet_foundation\anaconda3\lib\site-packages (from tensorflow) (1.68.1)
# Collecting tensorboard~=2.20.0 (from tensorflow)
#   Using cached tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: keras>=3.10.0 in d:\edunet_foundation\anaconda3\lib\site-packages (from tensorflow) (3.12.0)
# Requirement already satisfied: numpy>=1.26.0 in d:\edunet_foundation\anaconda3\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in d:\edunet_foundation\anaconda3\lib\site-packages (from tensorflow) (3.11.0)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Using cached ml_dtypes-0.5.3-cp312-cp312-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\edunet_foundation\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\edunet_foundation\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\edunet_foundation\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\edunet_foundation\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in d:\edunet_foundation\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.4.1)
# Requirement already satisfied: pillow in d:\edunet_foundation\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (10.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\edunet_foundation\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\edunet_foundation\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\edunet_foundation\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in d:\edunet_foundation\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (13.3.5)
# Requirement already satisfied: namex in d:\edunet_foundation\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in d:\edunet_foundation\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (0.12.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\edunet_foundation\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in d:\edunet_foundation\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\edunet_foundation\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in d:\edunet_foundation\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.0)
# Using cached tensorflow-2.20.0-cp312-cp312-win_amd64.whl (331.9 MB)
# Using cached ml_dtypes-0.5.3-cp312-cp312-win_amd64.whl (208 kB)
# Using cached tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
# Using cached protobuf-6.33.0-cp310-abi3-win_amd64.whl (436 kB)
# Installing collected packages: protobuf, ml_dtypes, tensorboard, tensorflow
#
#   Attempting uninstall: protobuf
#
#     Found existing installation: protobuf 4.25.8
#
#     Uninstalling protobuf-4.25.8:
#
#       Successfully uninstalled protobuf-4.25.8
#
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#    ---------------------------------------- 0/4 [protobuf]
#   Attempting uninstall: ml_dtypes
#    ---------------------------------------- 0/4 [protobuf]
#     Found existing installation: ml-dtypes 0.4.1
#    ---------------------------------------- 0/4 [protobuf]
#     Uninstalling ml-dtypes-0.4.1:
#    ---------------------------------------- 0/4 [protobuf]
#       Successfully uninstalled ml-dtypes-0.4.1
#    ---------------------------------------- 0/4 [protobuf]
#    ---------- ----------------------------- 1/4 [ml_dtypes]
#    ---------- ----------------------------- 1/4 [ml_dtypes]
#    ---------- ----------------------------- 1/4 [ml_dtypes]
#    ---------- ----------------------------- 1/4 [ml_dtypes]
#    ---------- ----------------------------- 1/4 [ml_dtypes]
#    ---------- ----------------------------- 1/4 [ml_dtypes]
#    ---------- ----------------------------- 1/4 [ml_dtypes]
#    ---------- ----------------------------- 1/4 [ml_dtypes]
#    ---------- ----------------------------- 1/4 [ml_dtypes]
#    ---------- ----------------------------- 1/4 [ml_dtypes]
#    ---------- ----------------------------- 1/4 [ml_dtypes]
#    ---------- ----------------------------- 1/4 [ml_dtypes]
#    ---------- ----------------------------- 1/4 [ml_dtypes]
#    ---------- ----------------------------- 1/4 [ml_dtypes]
#    ---------- ----------------------------- 1/4 [ml_dtypes]
#    ---------- ----------------------------- 1/4 [ml_dtypes]
#    ---------- ----------------------------- 1/4 [ml_dtypes]
#    ---------- ----------------------------- 1/4 [ml_dtypes]
#   Attempting uninstall: tensorboard
#    ---------- ----------------------------- 1/4 [ml_dtypes]
#     Found existing installation: tensorboard 2.17.1
#    ---------- ----------------------------- 1/4 [ml_dtypes]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#     Uninstalling tensorboard-2.17.1:
#    -------------------- ------------------- 2/4 [tensorboard]
#       Successfully uninstalled tensorboard-2.17.1
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorboard]
#   Attempting uninstall: tensorflow
#    -------------------- ------------------- 2/4 [tensorboard]
#     Found existing installation: tensorflow 2.17.0
#    -------------------- ------------------- 2/4 [tensorboard]
#     Uninstalling tensorflow-2.17.0:
#    -------------------- ------------------- 2/4 [tensorboard]
#       Successfully uninstalled tensorflow-2.17.0
#    -------------------- ------------------- 2/4 [tensorboard]
#    ------------------------------ --------- 3/4 [tensorflow]
#    ------------------------------ --------- 3/4 [tensorflow]
#    ------------------------------ --------- 3/4 [tensorflow]
#    ------------------------------ --------- 3/4 [tensorflow]
#   Rolling back uninstall of tensorflow
#    ------------------------------ --------- 3/4 [tensorflow]
#   Moving to d:\edunet_foundation\anaconda3\lib\site-packages\tensorflow-2.17.0.dist-info\
#    from D:\edunet_foundation\anaconda3\Lib\site-packages\~ensorflow-2.17.0.dist-info
#    ------------------------------ --------- 3/4 [tensorflow]
#    ------------------------------ --------- 3/4 [tensorflow]
# WARNING: Ignoring invalid distribution ~atplotlib (D:\edunet_foundation\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (D:\edunet_foundation\anaconda3\Lib\site-packages)
#   WARNING: Failed to remove contents in a temporary directory 'D:\edunet_foundation\anaconda3\Lib\site-packages\google\~-pb'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'D:\edunet_foundation\anaconda3\Lib\site-packages\~~_dtypes'.
#   You can safely remove it manually.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'D:\\edunet_foundation\\anaconda3\\Lib\\site-packages\\tensorflow\\compiler\\tf2tensorrt\\_pywrap_py_utils.pyd'
# Consider using the `--user` option or check the permissions.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input

# %% [markdown]
# 2. Feature Selection

# %%
# Load dataset (replace with your file path)
df = pd.read_csv("crop_yield.csv")
df.head()
# Out:
#   Region Soil_Type     Crop  Rainfall_mm  Temperature_Celsius  \
# 0   West     Sandy   Cotton       897.08                 27.7
# 1  South      Clay     Rice       992.67                 18.0
# 2  North      Loam   Barley       148.00                 29.8
# 3  North     Sandy  Soybean       986.87                 16.6
# 4  South      Silt    Wheat       730.38                 31.6
#
#    Fertilizer_Used  Irrigation_Used Weather_Condition  Days_to_Harvest  \
# 0            False             True            Cloudy              122
# 1             True             True             Rainy              140
# 2            False            False             Sunny              106
# 3            False             True             Rainy              146
# 4             True             True            Cloudy              110
#
#    Yield_tons_per_hectare
# 0                    6.56
# 1                    8.53
# 2                    1.13
# 3                    6.52
# 4                    7.25

# %%
# Now you can split features and target
X = df.drop('Yield_tons_per_hectare', axis=1)  # Features
y = df['Yield_tons_per_hectare']

# %%
# basic data exploration
for col in X.select_dtypes(include=["object"]).columns.to_list():
    print(f"Unique value in column - {col} are: {X[col].unique()}")
# Out:
# Unique value in column - Region are: ['West' 'South' 'North' 'East']
# Unique value in column - Soil_Type are: ['Sandy' 'Clay' 'Loam' 'Silt' 'Peaty' 'Chalky']
# Unique value in column - Crop are: ['Cotton' 'Rice' 'Barley' 'Soybean' 'Wheat' 'Maize']
# Unique value in column - Weather_Condition are: ['Cloudy' 'Rainy' 'Sunny']

# %% [markdown]
# 3. Data Preprocessing

# %%
# use one hot encoding to convert the object type columns to numeric column
X=pd.get_dummies(X)
X.head()
# Out:
#    Rainfall_mm  Temperature_Celsius  Fertilizer_Used  Irrigation_Used  \
# 0       897.08                 27.7            False             True
# 1       992.67                 18.0             True             True
# 2       148.00                 29.8            False            False
# 3       986.87                 16.6            False             True
# 4       730.38                 31.6             True             True
#
#    Days_to_Harvest  Region_East  Region_North  Region_South  Region_West  \
# 0              122        False         False         False         True
# 1              140        False         False          True        False
# 2              106        False          True         False        False
# 3              146        False          True         False        False
# 4              110        False         False          True        False
#
#    Soil_Type_Chalky  ...  Soil_Type_Silt  Crop_Barley  Crop_Cotton  \
# 0             False  ...           False        False         True
# 1             False  ...           False        False        False
# 2             False  ...           False         True        False
# 3             False  ...           False        False        False
# 4             False  ...            True        False        False
#
#    Crop_Maize  Crop_Rice  Crop_Soybean  Crop_Wheat  Weather_Condition_Cloudy  \
# 0       False      False         False       False                      True
# 1       False       True         False       False                     False
# 2       False      False         False       False                     False
# 3       False      False          True       False                     False
# 4       False      False         False        True                      True
#
#    Weather_Condition_Rainy  Weather_Condition_Sunny
# 0                    False                    False
# 1                     True                    False
# 2                    False                     True
# 3                     True                    False
# 4                    False                    False
#
# [5 rows x 24 columns]

# %%
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# 4. Split the data into training and testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# 5. Build the ANN model

# %%
model = Sequential()
model.add(Input(shape=(X_train.shape[1],)))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear')) # For regression output
# Out:
# D:\edunet_foundation\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# 6. Compile the model

# %%
model.compile(optimizer='adam', loss='mean_squared_error', metrics=["mae", "mse"])

# %% [markdown]
# 7. Train the model

# %%
model.fit(X_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 25000/25000 ━━━━━━━━━━━━━━━━━━━━ 38s 1ms/step - loss: 0.2861 - mae: 0.4147 - mse: 0.2861
# Epoch 2/10
# 25000/25000 ━━━━━━━━━━━━━━━━━━━━ 37s 1ms/step - loss: 0.2563 - mae: 0.4040 - mse: 0.2563
# Epoch 3/10
# 25000/25000 ━━━━━━━━━━━━━━━━━━━━ 36s 1ms/step - loss: 0.2553 - mae: 0.4032 - mse: 0.2553
# Epoch 4/10
# 25000/25000 ━━━━━━━━━━━━━━━━━━━━ 38s 2ms/step - loss: 0.2550 - mae: 0.4029 - mse: 0.2550
# Epoch 5/10
# 25000/25000 ━━━━━━━━━━━━━━━━━━━━ 37s 1ms/step - loss: 0.2544 - mae: 0.4025 - mse: 0.2544
# Epoch 6/10
# 25000/25000 ━━━━━━━━━━━━━━━━━━━━ 37s 1ms/step - loss: 0.2540 - mae: 0.4021 - mse: 0.2540
# Epoch 7/10
# 25000/25000 ━━━━━━━━━━━━━━━━━━━━ 39s 2ms/step - loss: 0.2537 - mae: 0.4018 - mse: 0.2537
# Epoch 8/10
# 25000/25000 ━━━━━━━━━━━━━━━━━━━━ 37s 1ms/step - loss: 0.2534 - mae: 0.4017 - mse: 0.2534
# Epoch 9/10
# 25000/25000 ━━━━━━━━━━━━━━━━━━━━ 37s 1ms/step - loss: 0.2530 - mae: 0.4014 - mse: 0.2530
# Epoch 10/10
# 25000/25000 ━━━━━━━━━━━━━━━━━━━━ 38s 2ms/step - loss: 0.2530 - mae: 0.4013 - mse: 0.2530

# %% [markdown]
# 8. Evaluate the model

# %%
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.2561 - mae: 0.4037 - mse: 0.2561
# Test Loss: [0.25613781809806824, 0.403695285320282, 0.25613781809806824]
